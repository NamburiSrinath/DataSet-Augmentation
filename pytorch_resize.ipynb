# %%
import torch
import torchvision.transforms.functional as fn
from torchvision import transforms

from PIL import Image

# %%
img = Image.open("airplane1.png")
image_tensor = transforms.ToTensor()
image_ten = image_tensor(img)

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=32x32>

# %%
image_ten2 = transforms.functional.resize(image_ten, size=(image_ten.shape[1] * 1, image_ten.shape[2] * 1))

# %%
import matplotlib.pyplot as plt

plt.imshow(image_ten2.numpy()[0])
